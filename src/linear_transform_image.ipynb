# %% [markdown]
# <a href="https://colab.research.google.com/github/songqsh/ma2071_v01/blob/master/src/linear_transform_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import all needed pakages here
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# __Goal__ Implement linear transformation on image
#
# - First, one shall download an image from https://github.com/songqsh/ma2071_v01/blob/master/src/wpilogo.jpg
# - and upload it, see left panel in colab

# %%
ls
# Out:
# sample_data/  wpilogo.jpg

# %%
# load this image as numpy array, and see it.
img = cv2.imread('wpilogo.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (400, 400, 3)

# %%
# the image size is recorded in rows, cols
rows,cols, _ = img.shape
print(rows, cols)
# Out:
# 400 400

# %% [markdown]
# - Linear Transform 1

# %%
lintrans = [[.5, 0], [0, .5]]
shift = [100, 100]
M = np.append(np.transpose(lintrans), [shift], axis = 0).transpose()

img1 = cv2.warpAffine(img, M, (int(1.25*cols),int(1.25*rows))) #package run your instruction
plt.imshow(img1)

# %% [markdown]
# - Linear Transform 2

# %%
lintrans = [[.5, 1], 
            [0., 1]] #this is linear transformation, where you need to replace
shift = [0., 0.]
M = np.append(np.transpose(lintrans), [shift], axis = 0).transpose()

img2 = cv2.warpAffine(img1, M, (int(1.25*cols),int(1.25*rows))) #package run your instruction
plt.imshow(img2)
